# %%
import json

# %%
obj = json.load(open("/home/ceb/Downloads/response_1720097172939.json"))
obj["layout"]
# Out:
# {'title': {'text': 't-SNE Embeddings of Database Mappings'},
#  'xaxis': {'title': {'text': 't-SNE Component 1'}},
#  'yaxis': {'title': {'text': 't-SNE Component 2'}},
#  'template': {'data': {'histogram2dcontour': [{'type': 'histogram2dcontour',
#      'colorbar': {'outlinewidth': 0, 'ticks': ''},
#      'colorscale': [[0.0, '#0d0887'],
#       [0.1111111111111111, '#46039f'],
#       [0.2222222222222222, '#7201a8'],
#       [0.3333333333333333, '#9c179e'],
#       [0.4444444444444444, '#bd3786'],
#       [0.5555555555555556, '#d8576b'],
#       [0.6666666666666666, '#ed7953'],
#       [0.7777777777777778, '#fb9f3a'],
#       [0.8888888888888888, '#fdca26'],
#       [1.0, '#f0f921']]}],
#    'choropleth': [{'type': 'choropleth',
#      'colorbar': {'outlinewidth': 0, 'ticks': ''}}],
#    'histogram2d': [{'type': 'histogram2d',
#      'colorbar': {'outlinewidth': 0, 'ticks': ''},
#      'colorscale': [[0.0, '#0d0887'],
#       [0.1111111111111111, '#46039f'],
# ...
